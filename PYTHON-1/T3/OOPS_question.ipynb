# %%
class SQ(Exception):
    def __init__(self,l):
        self.l=l
    def shift(self):
        self.l=l 
        try:
            if len(self.l)==0:
                raise Exception("list is empty")
        except Exception as e:
            print(e)
        else:
            d=l.pop(0)
            print("shift",l)
    def unshift(self,n):
        self.l=l
        l.insert(0,n)
        print("unshift",l)
    def push(self,p):
        self.l=l
        self.p=p
        l.append(p)
        print("push",l)
    def pop(self):
        self.l=l
        d2=l.pop(-1)
        print("pop",l)
    def remove(self):
        d3=max(l)
        d4=l.index(d3)
        d5=l.pop(d4)
        print("remove",l)
    def menu(self):
        po=True
        while po:
            print("1. shift")
            print("2. unshift")
            print("3. push")
            print("4. pop")
            print("5. remove")
            print("6. Exit")
            a=int(input("Enter your choice="))
            if a>=1 and a<=6:
                if a==1:
#                     print("1st element is deleted")
                    self.shift()
                elif a==2:
                    n=int(input("Enter number to insert at start"))
                    ob.unshift(n)
                elif a==3:
                    p=int(input("Enter number to insert at end"))
                    ob.push(p)
                elif a==4:
                    print("number will pop at end side")
                    ob.pop()
                elif a==5:
                    print("max number is called and deleted")
                    ob.remove()
                elif a==6:
                    print("Exiting...")
                    po=False
                else:
                    print("invalid input")
l=(eval(input("ENTER LIST=")))
ob=SQ(l)
ob.menu()
# Out:
# ENTER LIST=[]
# 1. shift
# 2. unshift
# 3. push
# 4. pop
# 5. remove
# 6. Exit
# Enter your choice=1
# 1st element is deleted
# list is empty
# 1. shift
# 2. unshift
# 3. push
# 4. pop
# 5. remove
# 6. Exit
# Enter your choice=6
# Exiting...

# %%
class WordPlay:
    def __init__(self,l):
        self.l=l
    def words_with_length(self,le):
        newl=[]
        for i in l:
            if len(i)==le:
                newl.append(i)
        print(newl)
    def starts_with(self,c1):
        sw=[]
        for i in l:
            if i[0]==c1:
                sw.append(i)
        print(sw)
    def ends_with(self,c2):
        ew=[]
        for i in l:
            if i[-1]==c2:
                ew.append(i)
        print(ew)
    def palindromes(self):
        p=[]
        self.l=l
        for i in l:
            rev=i[::-1]
            if i==rev:
                p.append(i)
        print(p)
    def only(self,w):
        on=[]
        o=set(w)
        for i in self.l:
            z=set(i)
            if o.intersection(z)==o:
                on.append(i)
        print(on)
    def avoid(self,w1):
        av=[]
        o1=set(w1)
        for i in self.l:
            z1=set(i)
            if o1.intersection(z1)==set():
                av.append(i)
        print(av)
l=["apple","banana","find","dictionary","set","Tuple","nayan"]
ob=WordPlay(l)
ob.words_with_length(5)
ob.starts_with("a")
ob.ends_with("e")
ob.palindromes()
ob.only("bna")
ob.avoid("a")
# Out:
# ['apple', 'Tuple', 'nayan']
# ['apple']
# ['apple', 'Tuple']
# ['nayan']
# ['banana']
# ['find', 'set', 'Tuple']
