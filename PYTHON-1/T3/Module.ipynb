# %%
import os

# %%
os.getcwd()

# %%
os.chdir(r"C:\Users\LJENG\Desktop\B4")

# %%
os.getcwd()

# %%
os.mkdir("T3")

# %%
# %%writefile 1.txt
# hello

# %%
os.rename("Demo.txt","4.txt")

# %%
#delete file
#if we want to delete file in our current working directory then we only give name of file
#if we want to delete file in other folder then we have to give path
os.remove(os.getcwd()+"\\4.txt") #delete demo.txt

# %%
os.rmdir(os.getcwd()+"\\T3")

# %%
os.chdir(r"C:\Users\LJENG\Desktop\T3_PY_129")
os.listdir()

# %%
#Example:-make file in desktop and add three nore file in it
os.chdir(r"C:\Users\LJENG\Desktop")
#os.mkdir("7")
os.getcwd()
os.chdir(r"C:\\Users\\LJENG\\Desktop\\7")

# %%
os.mkdir("1")
os.mkdir("2")
os.mkdir("3")

# %%
# %%writefile aplr.py

def length(n):
    return len(n)
def reverse(n):
    return n[::-1]

# %%
import aplr as p
n=input("Enter string")
print(p.length(n))
print(p.reverse(n))

# %%
# %%writefile first_word.py

def first(x):
    n=x.split(" ")
    return n[0]
# Out:
# Writing first_word.py

# %%
import first_word as f
x=str(input("Enter string="))
print(f.first(x))
# Out:
# Enter string=this is my code
# this
