# %%
import datetime
from datetime import time,date,datetime
x=datetime.now()
print(x)       #2025-12-04 13:16:09.035489
print(x.year)  #2025
print(x.month) #12

y=datetime(2025,12,31,15,10,43)
print(y)      #2025-12-31 15:10:43
# Out:
# 2025-12-04 13:25:05.427018
# 2025
# 12
# 2025-12-31 15:10:43

# %%
a=datetime(2006,12,21)
b=datetime.now()
print(f"number of days{b-a}")
# Out:
# number of days6923 days, 13:32:04.408210
